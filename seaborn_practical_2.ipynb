# %%
import seaborn as sns
from scipy.stats import norm
import matplotlib.pyplot as plt

# %%
tips_df=sns.load_dataset("tips")
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.distplot(tips_df["size"])
# Out:
# C:\Users\Junaid Ahmed\AppData\Local\Temp\ipykernel_5520\1953057503.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips_df["size"])
# <Axes: xlabel='size', ylabel='Density'>

# %%
sns.distplot(tips_df["total_bill"])
# Out:
# C:\Users\Junaid Ahmed\AppData\Local\Temp\ipykernel_5520\3661633761.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips_df["total_bill"])
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(tips_df["total_bill"],bins=10)
# Out:
# C:\Users\Junaid Ahmed\AppData\Local\Temp\ipykernel_5520\2753027926.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips_df["total_bill"],bins=10)
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(tips_df["total_bill"],bins=100)
# Out:
# C:\Users\Junaid Ahmed\AppData\Local\Temp\ipykernel_5520\2393310173.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips_df["total_bill"],bins=100)
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(tips_df["total_bill"],hist=False)
# Out:
# C:\Users\Junaid Ahmed\AppData\Local\Temp\ipykernel_5520\2983156546.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips_df["total_bill"],hist=False)
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(tips_df["total_bill"],kde=False)
# Out:
# C:\Users\Junaid Ahmed\AppData\Local\Temp\ipykernel_5520\2289134297.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips_df["total_bill"],kde=False)
# <Axes: xlabel='total_bill'>

# %%
sns.distplot(tips_df["total_bill"],rug=True)
# Out:
# C:\Users\Junaid Ahmed\AppData\Local\Temp\ipykernel_5520\4127717892.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips_df["total_bill"],rug=True)
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(tips_df["total_bill"],fit=norm,kde=False)
# Out:
# C:\Users\Junaid Ahmed\AppData\Local\Temp\ipykernel_5520\1723653032.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips_df["total_bill"],fit=norm,kde=False)
# <Axes: xlabel='total_bill'>

# %%
sns.distplot(tips_df["total_bill"],color="r")
# Out:
# C:\Users\Junaid Ahmed\AppData\Local\Temp\ipykernel_5520\1317507489.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips_df["total_bill"],color="r")
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(tips_df["total_bill"],vertical=True)
# Out:
# C:\Users\Junaid Ahmed\AppData\Local\Temp\ipykernel_5520\3120095513.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips_df["total_bill"],vertical=True)
# <Axes: xlabel='Density', ylabel='total_bill'>

# %%
sns.distplot(tips_df["total_bill"],norm_hist=False,)
# Out:
# C:\Users\Junaid Ahmed\AppData\Local\Temp\ipykernel_5520\2166266321.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips_df["total_bill"],norm_hist=False,)
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(tips_df["total_bill"],axlabel="Total bill")
# Out:
# C:\Users\Junaid Ahmed\AppData\Local\Temp\ipykernel_5520\3604447632.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips_df["total_bill"],axlabel="Total bill")
# <Axes: xlabel='Total bill', ylabel='Density'>

# %%
sns.distplot(tips_df["total_bill"],label="total bill")
plt.title("histogram of total bill")
plt.legend()
plt.show()
# Out:
# C:\Users\Junaid Ahmed\AppData\Local\Temp\ipykernel_5520\3017752380.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips_df["total_bill"],label="total bill")

# %%
sns.set()
sns.distplot(tips_df["total_bill"],label="total bill")
plt.title("histogram of total bill")
plt.legend()
plt.show()
# Out:
# C:\Users\Junaid Ahmed\AppData\Local\Temp\ipykernel_5520\3650892268.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips_df["total_bill"],label="total bill")

# %%
tips_df.total_bill.sort_values()
# Out:
# 67      3.07
# 92      5.75
# 111     7.25
# 172     7.25
# 149     7.51
#        ...
# 182    45.35
# 156    48.17
# 59     48.27
# 212    48.33
# 170    50.81
# Name: total_bill, Length: 244, dtype: float64

# %%
bins=[1,5,10,15,20,25,30,35,40,45,50,55]
sns.set()
plt.figure(figsize=(15,8))
sns.distplot(tips_df["total_bill"],bins=bins,)
plt.xticks(bins)
plt.title("histogram of total bill")
plt.show()
# Out:
# C:\Users\Junaid Ahmed\AppData\Local\Temp\ipykernel_5520\2612767224.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips_df["total_bill"],bins=bins,)

# %%
plt.figure(figsize=(15,8))
sns.distplot(tips_df["total_bill"],hist_kws={"color":"b","edgecolor":"m","linewidth":5,"linestyle":"--","alpha":0.9},
             kde_kws={"color":"r","linewidth":5,"linestyle":"--","alpha":0.9},
            rug=True)
# Out:
# C:\Users\Junaid Ahmed\AppData\Local\Temp\ipykernel_5520\1123875892.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips_df["total_bill"],hist_kws={"color":"b","edgecolor":"m","linewidth":5,"linestyle":"--","alpha":0.9},
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
plt.figure(figsize=(15,8))
sns.distplot(tips_df["total_bill"],hist_kws={"color":"b","edgecolor":"m","linewidth":5,"linestyle":"--","alpha":0.9},
             kde_kws={"color":"r","linewidth":5,"linestyle":"--","alpha":0.9},
            rug=True,
            rug_kws={"color":"k","edgecolor":"m","linewidth":5,"linestyle":"--","alpha":0.9})
# Out:
# C:\Users\Junaid Ahmed\AppData\Local\Temp\ipykernel_5520\379008299.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips_df["total_bill"],hist_kws={"color":"b","edgecolor":"m","linewidth":5,"linestyle":"--","alpha":0.9},
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
plt.figure(figsize=(15,8))
sns.distplot(tips_df["total_bill"],hist_kws={"color":"b","edgecolor":"m","linewidth":5,"linestyle":"--","alpha":0.9},
             kde=False,
             fit=norm,
             fit_kws={"color":"y","linewidth":5,"linestyle":"--","alpha":0.9},
            rug=True,
            rug_kws={"color":"k","edgecolor":"m","linewidth":5,"linestyle":"--","alpha":0.9})
# Out:
# C:\Users\Junaid Ahmed\AppData\Local\Temp\ipykernel_5520\171923035.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips_df["total_bill"],hist_kws={"color":"b","edgecolor":"m","linewidth":5,"linestyle":"--","alpha":0.9},
# <Axes: xlabel='total_bill'>

# %%
plt.figure(figsize=(15,8))
sns.distplot(tips_df["total_bill"],hist_kws={"color":"b","edgecolor":"m","linewidth":5,"linestyle":"--","alpha":0.9},
             kde=False,
             fit=norm,
             fit_kws={"color":"y","linewidth":5,"linestyle":"--","alpha":0.9},
            rug=True,
            rug_kws={"color":"k","edgecolor":"m","linewidth":5,"linestyle":"--","alpha":0.9},label="TB")
plt.title("histogram of Restorant total bill",fontsize=20)
plt.xlabel("total bill",fontsize=15)
plt.legend()
plt.show()
# Out:
# C:\Users\Junaid Ahmed\AppData\Local\Temp\ipykernel_5520\2149838992.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips_df["total_bill"],hist_kws={"color":"b","edgecolor":"m","linewidth":5,"linestyle":"--","alpha":0.9},
